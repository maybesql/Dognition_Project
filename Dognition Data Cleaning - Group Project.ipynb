# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel ('dataset 1/dognition_data_aggregated_by_dogid.xlsx')

# %%
df.head().T
# Out:
#                                                                                     0  \
# Dog ID                                           fd27b272-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                              21
# Mean ITI (days)                                                             28.201076
# Mean ITI (minutes)                                                       40609.549167
# Median ITI (days)                                                            0.004687
# Median ITI (minutes)                                                             6.75
# Time diff between first and last game (days)                               564.021516
# Time diff between first and last game (minutes)                         812190.983333
# User ID                                          ce134e42-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                         female
# ...

# %%
df.tail().T
# Out:
#                                                                                 17981  \
# Dog ID                                           fdc235e0-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                               7
# Mean ITI (days)                                                              0.009408
# Mean ITI (minutes)                                                          13.547222
# Median ITI (days)                                                            0.004786
# Median ITI (minutes)                                                         6.891667
# Time diff between first and last game (days)                                 0.056447
# Time diff between first and last game (minutes)                             81.283333
# User ID                                          ce9b2aba-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                           male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17986 entries, 0 to 17985
# Data columns (total 30 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Dog ID                                           17986 non-null  object
#  1   Total Tests Completed                            17986 non-null  int64
#  2   Mean ITI (days)                                  16718 non-null  float64
#  3   Mean ITI (minutes)                               16718 non-null  float64
#  4   Median ITI (days)                                16718 non-null  float64
#  5   Median ITI (minutes)                             16718 non-null  float64
#  6   Time diff between first and last game (days)     17986 non-null  float64
#  7   Time diff between first and last game (minutes)  17986 non-null  float64
#  8   User ID                                          17985 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Dog ID                                                0
# Total Tests Completed                                 0
# Mean ITI (days)                                    1268
# Mean ITI (minutes)                                 1268
# Median ITI (days)                                  1268
# Median ITI (minutes)                               1268
# Time diff between first and last game (days)          0
# Time diff between first and last game (minutes)       0
# User ID                                               1
# Gender                                                1
# Birthday                                              1
# Breed                                                16
# Breed_Type                                            1
# Breed_Group                                           1
# Weight                                                1
# Dog_Fixed                                             1
# DNA_Tested                                            1
# ...

# %%
df2 = pd.read_excel ('dataset 1/dognition_data_no_aggregation_with_zip_code_correction.xlsx')

# %%
df2.head().T
# Out:
#                                                      0  \
# Created_at                         2013-05-13 16:17:00
# Updated_at                         2013-05-13 16:17:00
# User_ID           ce134a78-7144-11e5-ba71-058fbc01cf0b
# Dog_ID            fd3d1b44-7144-11e5-ba71-058fbc01cf0b
# Test_name                                 Yawn Warm-up
# Subcategory_name                               Empathy
# Gender                                            male
# Birthday                                          2009
# Breed                                         Shih Tzu
# Breed_Type                                  Pure Breed
# Breed_Group                                        Toy
# Weight                                             190
# Dog_Fixed                                          1.0
# DNA_Tested                                         0.0
# Dimension                                     einstein
# Sign_in_Count                                      310
# ...

# %%
df2.tail().T
# Out:
#                                                 177476  \
# Created_at                         2013-05-14 08:45:00
# Updated_at                         2013-05-14 08:45:00
# User_ID           ce2777e6-7144-11e5-ba71-058fbc01cf0b
# Dog_ID            fd444202-7144-11e5-ba71-058fbc01cf0b
# Test_name                              One Cup Warm-up
# Subcategory_name                                Memory
# Gender                                            male
# Birthday                                          2012
# Breed                                            Mixed
# Breed_Type            Mixed Breed/ Other/ I Don't Know
# Breed_Group                                        NaN
# Weight                                              50
# Dog_Fixed                                          1.0
# DNA_Tested                                         0.0
# Dimension                                          NaN
# Sign_in_Count                                       12
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177481 entries, 0 to 177480
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Created_at        177481 non-null  datetime64[ns]
#  1   Updated_at        177481 non-null  datetime64[ns]
#  2   User_ID           177481 non-null  object
#  3   Dog_ID            177481 non-null  object
#  4   Test_name         177481 non-null  object
#  5   Subcategory_name  177481 non-null  object
#  6   Gender            177481 non-null  object
#  7   Birthday          177481 non-null  int64
#  8   Breed             177279 non-null  object
#  9   Breed_Type        177481 non-null  object
#  10  Breed_Group       88923 non-null   object
#  11  Weight            177481 non-null  int64
#  12  Dog_Fixed         175317 non-null  float64
#  13  DNA_Tested        52968 non-null   float64
#  14  Dimension         91070 non-null   object
# ...

# %%
df2.isnull().sum()
# Out:
# Created_at               0
# Updated_at               0
# User_ID                  0
# Dog_ID                   0
# Test_name                0
# Subcategory_name         0
# Gender                   0
# Birthday                 0
# Breed                  202
# Breed_Type               0
# Breed_Group          88558
# Weight                   0
# Dog_Fixed             2164
# DNA_Tested          124513
# Dimension            86411
# Sign_in_Count            0
# Max_Dogs                 0
# Membership_ID         1146
# Subscribed               0
# City                 39004
# State                38989
# Zip                  39354
# Country              37965
# Exclude             164718
# Free_Start_User     141160
# Last_Active_At       29605
# Membership_Type       1081
# Rating              175608
# Rank_by_UserID         456
# Rank_by_DogID          456
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17981    False
# 17982    False
# 17983    False
# 17984    False
# 17985    False
# Length: 17986, dtype: bool

# %%
df2.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 177476    False
# 177477    False
# 177478    False
# 177479    False
# 177480    False
# Length: 177481, dtype: bool

# %%
df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
# Out:
#                                      Dog ID  Total Tests Completed  \
# 0      fd27b272-7144-11e5-ba71-058fbc01cf0b                     21
# 1      fd27b5ba-7144-11e5-ba71-058fbc01cf0b                     20
# 2      fd27b6b4-7144-11e5-ba71-058fbc01cf0b                      2
# 3      fd27b79a-7144-11e5-ba71-058fbc01cf0b                     11
# 4      fd27b86c-7144-11e5-ba71-058fbc01cf0b                     31
# ...                                     ...                    ...
# 17981  fdc235e0-7144-11e5-ba71-058fbc01cf0b                      7
# 17982  fdc23a68-7144-11e5-ba71-058fbc01cf0b                      1
# 17983  fdc23ba8-7144-11e5-ba71-058fbc01cf0b                     20
# 17984  fdc23e96-7144-11e5-ba71-058fbc01cf0b                      4
# 17985  fdc2417a-7144-11e5-ba71-058fbc01cf0b                      6
#
#        Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 0            28.201076        40609.549167           0.004687
# ...

# %%
#0 rows are removed from df

# %%
df2.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
# Out:
#                 Created_at          Updated_at  \
# 0      2013-05-13 16:17:00 2013-05-13 16:17:00
# 1      2013-05-22 18:54:00 2013-05-22 18:54:00
# 2      2013-05-22 18:55:00 2013-05-22 18:55:00
# 3      2013-05-22 18:56:00 2013-05-22 18:56:00
# 4      2013-05-22 18:58:00 2013-05-22 18:58:00
# ...                    ...                 ...
# 177476 2013-05-14 08:45:00 2013-05-14 08:45:00
# 177477 2013-05-14 08:50:00 2013-05-14 08:50:00
# 177478 2013-05-14 08:54:00 2013-05-14 08:54:00
# 177479 2013-05-19 04:45:00 2013-05-19 04:45:00
# 177480 2013-05-19 05:05:00 2013-05-19 05:05:00
#
#                                      User_ID  \
# 0       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 1       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 2       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 3       ce134a78-7144-11e5-ba71-058fbc01cf0b
# 4       ce134a78-7144-11e5-ba71-058fbc01cf0b
# ...                                      ...
# 177476  ce2777e6-7144-11e5-ba71-058fbc01cf0b
# ...

# %%
#216 rows of duplicate records are removed from df2

# %%
df.describe().T
# Out:
#                                                    count          mean  \
# Total Tests Completed                            17986.0      9.807239
# Mean ITI (days)                                  16718.0      2.300726
# Mean ITI (minutes)                               16718.0   3313.045589
# Median ITI (days)                                16718.0      0.275986
# Median ITI (minutes)                             16718.0    397.420037
# Time diff between first and last game (days)     17986.0     25.140728
# Time diff between first and last game (minutes)  17986.0  36202.648857
# Birthday                                         17985.0   2009.932388
# Weight                                           17985.0     41.485683
# Dog_Fixed                                        17985.0      0.850876
# DNA_Tested                                       17985.0      0.036697
# Sign_in_Count                                    17985.0      8.329386
# ...

# %%
df2.describe().T
# Out:
#                    count         mean        std     min     25%     50%  \
# Birthday        177481.0  2009.898265   3.280318  1982.0  2008.0  2011.0
# Weight          177481.0    42.683442  29.171277     0.0    20.0    40.0
# Dog_Fixed       175317.0     0.876144   0.329418     0.0     1.0     1.0
# DNA_Tested       52968.0     0.141633   0.348676     0.0     0.0     0.0
# Sign_in_Count   177481.0    11.441771  69.452489     0.0     3.0     5.0
# Max_Dogs        177481.0     1.373251   1.545094     0.0     1.0     1.0
# Membership_ID   176335.0     7.113250   4.201120     1.0     2.0    10.0
# Subscribed      177481.0     0.665192   0.471925     0.0     0.0     1.0
# Rating            1873.0     2.104645   2.514859     0.0     0.0     1.0
# Rank_by_UserID  177025.0    14.008728  49.376213     1.0     3.0     8.0
# Rank_by_DogID   177025.0     8.494088   6.670537     1.0     3.0     7.0
#
#                    75%     max
# Birthday        2012.0  2015.0
# ...

# %%
df[df['Breed'].isna()]
# Out:
#                                      Dog ID  Total Tests Completed  \
# 878    fd431242-7144-11e5-ba71-058fbc01cf0b                     20
# 1060   fd43ce08-7144-11e5-ba71-058fbc01cf0b                     30
# 1687   fd461262-7144-11e5-ba71-058fbc01cf0b                      4
# 2062   fd47f686-7144-11e5-ba71-058fbc01cf0b                     11
# 2109   fd481918-7144-11e5-ba71-058fbc01cf0b                     20
# 2115   fd4821c4-7144-11e5-ba71-058fbc01cf0b                     20
# 2126   fd48393e-7144-11e5-ba71-058fbc01cf0b                     20
# 2140   fd4840aa-7144-11e5-ba71-058fbc01cf0b                     20
# 2157   fd48509a-7144-11e5-ba71-058fbc01cf0b                     20
# 2633   fd4b48d6-7144-11e5-ba71-058fbc01cf0b                      7
# 2944   fd503396-7144-11e5-ba71-058fbc01cf0b                      4
# 3052   fd513d90-7144-11e5-ba71-058fbc01cf0b                     11
# 3443   fd539734-7144-11e5-ba71-058fbc01cf0b                      4
# ...

# %%
df[df['Breed_Type'].isna()]
# Out:
#                                      Dog ID  Total Tests Completed  \
# 16643  fdbb6b7a-7144-11e5-ba71-058fbc01cf0b                     20
#
#        Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 16643         0.002747             3.95614           0.001644
#
#        Median ITI (minutes)  Time diff between first and last game (days)  \
# 16643              2.366667                                      0.052199
#
#        Time diff between first and last game (minutes) User ID Gender  ...  \
# 16643                                        75.166667     NaN    NaN  ...
#
#        Membership_ID Subscribed City State  Zip  Country  Exclude  \
# 16643            NaN        NaN  NaN   NaN  NaN      NaN      NaN
#
#       Free_Start_User  Last_Active_At  Membership_Type
# 16643             NaN             NaN              NaN
#
# [1 rows x 30 columns]

# %%
df[df['User ID'].isna()]
# Out:
#                                      Dog ID  Total Tests Completed  \
# 16643  fdbb6b7a-7144-11e5-ba71-058fbc01cf0b                     20
#
#        Mean ITI (days)  Mean ITI (minutes)  Median ITI (days)  \
# 16643         0.002747             3.95614           0.001644
#
#        Median ITI (minutes)  Time diff between first and last game (days)  \
# 16643              2.366667                                      0.052199
#
#        Time diff between first and last game (minutes) User ID Gender  ...  \
# 16643                                        75.166667     NaN    NaN  ...
#
#        Membership_ID Subscribed City State  Zip  Country  Exclude  \
# 16643            NaN        NaN  NaN   NaN  NaN      NaN      NaN
#
#       Free_Start_User  Last_Active_At  Membership_Type
# 16643             NaN             NaN              NaN
#
# [1 rows x 30 columns]

# %%
df2.loc[df2['Dog_ID'] == 'fdbb6b7a-7144-11e5-ba71-058fbc01cf0b']
# Out:
# Empty DataFrame
# Columns: [Created_at, Updated_at, User_ID, Dog_ID, Test_name, Subcategory_name, Gender, Birthday, Breed, Breed_Type, Breed_Group, Weight, Dog_Fixed, DNA_Tested, Dimension, Sign_in_Count, Max_Dogs, Membership_ID, Subscribed, City, State, Zip, Country, Exclude, Free_Start_User, Last_Active_At, Membership_Type, Rating, Rank_by_UserID, Rank_by_DogID]
# Index: []
#
# [0 rows x 30 columns]

# %%
#Since the only 1 missing value in most of the columns belong to the same row, drop row with missing value in Breed
df3 = df.dropna(subset=['Breed'])

# %%
#check missing value count again
df3.isnull().sum()
# Out:
# Dog ID                                                0
# Total Tests Completed                                 0
# Mean ITI (days)                                    1268
# Mean ITI (minutes)                                 1268
# Median ITI (days)                                  1268
# Median ITI (minutes)                               1268
# Time diff between first and last game (days)          0
# Time diff between first and last game (minutes)       0
# User ID                                               0
# Gender                                                0
# Birthday                                              0
# Breed                                                 0
# Breed_Type                                            0
# Breed_Group                                           0
# Weight                                                0
# Dog_Fixed                                             0
# DNA_Tested                                            0
# ...

# %%
#drop columns with 
cdf = df3.drop(columns=['Mean ITI (days)', 'Mean ITI (minutes)', 'Median ITI (days)', 'Median ITI (minutes)'])

# %%
cdf.isnull().sum()
# Out:
# Dog ID                                                0
# Total Tests Completed                                 0
# Time diff between first and last game (days)          0
# Time diff between first and last game (minutes)       0
# User ID                                               0
# Gender                                                0
# Birthday                                              0
# Breed                                                 0
# Breed_Type                                            0
# Breed_Group                                           0
# Weight                                                0
# Dog_Fixed                                             0
# DNA_Tested                                            0
# Dimension                                             0
# Sign_in_Count                                         0
# Max_Dogs                                              0
# Membership_ID                                         0
# ...

# %%
cdf.loc[cdf['Exclude'] == 1]
# Out:
#                                      Dog ID  Total Tests Completed  \
# 4      fd27b86c-7144-11e5-ba71-058fbc01cf0b                     31
# 6      fd27ba1a-7144-11e5-ba71-058fbc01cf0b                     27
# 43     fd27e9a4-7144-11e5-ba71-058fbc01cf0b                     22
# 45     fd27ed46-7144-11e5-ba71-058fbc01cf0b                     25
# 69     fd3cf718-7144-11e5-ba71-058fbc01cf0b                     17
# ...                                     ...                    ...
# 6078   fd699cf0-7144-11e5-ba71-058fbc01cf0b                      5
# 8998   fd73b53c-7144-11e5-ba71-058fbc01cf0b                      7
# 10867  fd7af63a-7144-11e5-ba71-058fbc01cf0b                     20
# 11062  fd7b9f4a-7144-11e5-ba71-058fbc01cf0b                      4
# 11210  fd7c1ace-7144-11e5-ba71-058fbc01cf0b                      7
#
#        Time diff between first and last game (days)  \
# 4                                        232.027627
# 6                                        160.955336
# ...

# %%
#drop rows that Dognition indicats the entries should be excluded
cdf1 = cdf[cdf.Exclude !=1]

# %%
cdf1.loc[cdf1['Exclude'] == 1]
# Out:
# Empty DataFrame
# Columns: [Dog ID, Total Tests Completed, Time diff between first and last game (days), Time diff between first and last game (minutes), User ID, Gender, Birthday, Breed, Breed_Type, Breed_Group, Weight, Dog_Fixed, DNA_Tested, Dimension, Sign_in_Count, Max_Dogs, Membership_ID, Subscribed, City, State, Zip, Country, Exclude, Free_Start_User, Last_Active_At, Membership_Type]
# Index: []
#
# [0 rows x 26 columns]

# %%
#Since the rows flagged as "Exclude" are removed, drop column 'Exclude' because it is not needed anymore.
cdf2 = cdf1.drop(columns=['Exclude'])

# %%
cdf2.head().T
# Out:
#                                                                                     0  \
# Dog ID                                           fd27b272-7144-11e5-ba71-058fbc01cf0b
# Total Tests Completed                                                              21
# Time diff between first and last game (days)                               564.021516
# Time diff between first and last game (minutes)                         812190.983333
# User ID                                          ce134e42-7144-11e5-ba71-058fbc01cf0b
# Gender                                                                         female
# Birthday                                                                       2011.0
# Breed                                                              Labrador Retriever
# Breed_Type                                                                 Pure Breed
# Breed_Group                                                                  Sporting
# ...
